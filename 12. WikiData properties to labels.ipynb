# %%
import pandas as pd
import pickle as pkl
import time
from collections import Counter
import numpy as np
import matplotlib.pylab as plt
from qwikidata.entity import WikidataItem, WikidataLexeme, WikidataProperty
from qwikidata.linked_data_interface import get_entity_dict_from_api

# %%
authors = pd.read_csv("data/final_authors_after_properties.csv", low_memory=False, index_col=0).fillna("''")

# %%
authors.columns
# Out:
# Index(['ISBN', 'title', 'author', 'alt_title', 'alt_author', 'correct_author',
#        'alt_first_author', 'viaf_id', 'QID', 'sexuality', 'country',
#        'language', 'religion', 'gender', 'ethnicity', 'birthyear',
#        'deathyear'],
#       dtype='object')

# %% [markdown]
# # Properties QIDs to labels

# %% [markdown]
# ## Sort out

# %%
authors.columns[9:]
# Out:
# Index(['sexuality', 'country', 'language', 'religion', 'gender', 'ethnicity',
#        'birthyear', 'deathyear'],
#       dtype='object')

# %%
for col in authors.columns[9:]:
    authors[col] = authors[col].apply(lambda d: d.split('[')[1][1:] if d[0]=="[" else d).apply(lambda d: d.split(']')[0][:-1] if d[-1]=="]" else d).str.replace("'","")

# %%
property_labels = {}
for col in authors.columns[9:-2]:
    property_labels[col] = []
    unique_values = authors[col].unique()
    for value in unique_values:
        if value!="":
            values = value.split(", ")
            for val in values:
                if val not in property_labels[col]:
                    property_labels[col].append(val)

# %% [markdown]
# ## Turn qid to label

# %%
start = time.time()
for col in ["religion","gender","ethnicity"]:
    new_vals = []
    for val in property_labels[col]:
        prop_dict = get_entity_dict_from_api(val)
        try:
            new_val = prop_dict["labels"]["en"]["value"]      
        except:
            # take the first if english doesn't exist
            print(prop_dict["labels"])
            new_val = list(prop_dict["labels"].values())[0]["value"]
        new_vals.append(new_val)
    property_labels[col].append(new_vals)
    print(time.time() - start)
    print(col)
# Out:
# {'de': {'language': 'de', 'value': 'Surmang-Kagyü'}}
# 57.503150939941406
# religion
# 60.886780738830566
# gender
# {'be': {'language': 'be', 'value': 'Чэхі, племя'}, 'ru': {'language': 'ru', 'value': 'Чехи (племя)'}, 'cs': {'language': 'cs', 'value': 'Čechové'}, 'ro': {'language': 'ro', 'value': 'cehi'}}
# {'es': {'language': 'es', 'value': 'Wasco'}, 'ca': {'language': 'ca', 'value': 'wasco'}, 'vec': {'language': 'vec', 'value': 'wasco'}}
# 136.00067710876465
# ethnicity

# %%
for col in property_labels.keys():
    vals = property_labels[col]
    rang = len(vals) - 1
    label_list = vals[-1]
    label_dict = {}
    for i in range(rang):
        label_dict[vals[i]] = label_list[i]
    property_labels[col] = label_dict
    print(col)
# Out:
# sexuality
# country
# language
# religion
# gender
# ethnicity

# %%
with open("data/property_dict.pkl", "wb") as f:
    pkl.dump(property_labels,f)

# %%
with open("data/property_dict.pkl", "rb") as f:
    property_labels = pkl.load(f)

# %%
property_labels
# Out:
# {'sexuality': {'Q6636': 'homosexuality',
#   'Q6649': 'lesbianism',
#   'Q339014': 'non-heterosexuality',
#   'Q43200': 'bisexuality',
#   'Q592': 'gay',
#   'Q1035954': 'heterosexuality',
#   'Q724351': 'asexuality',
#   'Q271534': 'pansexuality'},
#  'country': {'Q16': 'Canada',
#   'Q30': 'United States of America',
#   'Q38': 'Italy',
#   'Q21': 'England',
#   'Q145': 'United Kingdom',
#   'Q183': 'Germany',
#   'Q174193': 'United Kingdom of Great Britain and Ireland',
#   'Q161885': 'Great Britain',
#   'Q27': 'Republic of Ireland',
#   'Q142': 'France',
#   'Q2305208': 'Russian Socialist Federative Soviet Republic',
#   'Q15180': 'Soviet Union',
#   'Q713750': 'West Germany',
#   'Q159': 'Russia',
#   'Q34266': 'Russian Empire',
#   'Q207272': 'Second Polish Republic',
#   'Q129286': 'British India',
#   'Q1775277': 'Dominion of India',
#   'Q668': 'India',
#   'Q148540': 'Republic of Florence',
#   'Q25': 'Wales',
#   'Q739': 'Colombia',
#   'Q408': 'Australia',
#   'Q45': 'Portugal',
#   'Q35': 'Denmark',
#   'Q29': 'Spain',
#   'Q2227570': 'Duchy of Württemberg',
#   'Q155': 'Brazil',
#   'Q43': 'Turkey',
#   'Q213': 'Czech Republic',
#   'Q33946': 'Czechoslovakia',
#   'Q20': 'Norway',
#   'Q298': 'Chile',
#   'Q40': 'Austria',
#   'Q664': 'New Zealand',
#   'Q179876': 'Kingdom of England',
#   'Q96': 'Mexico',
#   'Q414': 'Argentina',
#   'Q36': 'Poland',
#   'Q37': 'Lithuania',
#   'Q150': 'French',
#   'Q953': 'Zambia',
#   'Q258': 'South Africa',
#   'Q28513': 'Austria-Hungary',
#   'Q41304': 'Weimar Republic',
#   'Q801': 'Israel',
#   'Q754': 'Trinidad and Tobago',
#   'Q70802': 'French Third Republic',
#   'Q39': 'Switzerland',
#   'Q1036': 'Uganda',
#   'Q31': 'Belgium',
#   'Q756617': 'Kingdom of Denmark',
#   'Q218': 'Romania',
#   'Q17': 'Japan',
#   'Q844930': 'Classical Athens',
#   'Q29999': 'Kingdom of the Netherlands',
#   'Q148': "People's Republic of China",
#   'Q16957': 'German Democratic Republic',
#   'Q854': 'Sri Lanka',
#   'Q43287': 'German Empire',
#   'Q155570': 'Saxe-Weimar-Eisenach',
#   'Q172579': 'Kingdom of Italy',
#   'Q34': 'Sweden',
#   'Q12560': 'Ottoman Empire',
#   'Q790': 'Haiti',
#   'Q139319': 'Russian Republic',
#   'Q2184': 'Russian Soviet Federative Socialist Republic',
#   'Q419': 'Peru',
#   'Q28': 'Hungary',
#   'Q232': 'Kazakhstan',
#   'Q219': 'Bulgaria',
#   'Q219060': 'State of Palestine',
#   'Q33': 'Finland',
#   'Q268970': 'Republic of German-Austria',
#   'Q518101': 'First Republic of Austria',
#   'Q176495': 'Federal State of Austria',
#   'Q7318': 'Nazi Germany',
#   'Q1747689': 'Ancient Rome',
#   'Q837855': 'Qi',
#   'Q912068': 'Wu',
#   'Q1423581': 'Italian Regency of Carnaro',
#   'Q548114': 'Free State of Fiume',
#   'Q191077': 'Kingdom of Yugoslavia',
#   'Q153128': 'Independent State of Croatia',
#   'Q1277557': 'Democratic Federal Yugoslavia',
#   'Q83286': 'Socialist Federal Republic of Yugoslavia',
#   'Q41': 'Greece',
#   'Q794': 'Iran',
#   'Q211274': "Polish People's Republic",
#   'Q766': 'Jamaica',
#   'Q1006': 'Guinea',
#   'Q26': 'Northern Ireland',
#   'Q224': 'Croatia',
#   'Q17252': 'Tibet',
#   'Q13426199': 'Republic of China',
#   'Q822': 'Lebanon',
#   'Q1206012': 'German Reich',
#   'Q1028': 'Morocco',
#   'Q70972': 'Kingdom of France',
#   'Q69323': 'Kingdom of France',
#   'Q811': 'Nicaragua',
#   'Q786': 'Dominican Republic',
#   'Q230791': 'Kingdom of Scotland',
#   'Q869': 'Thailand',
#   'Q533534': 'Cisleithania',
#   'Q127861': 'Khedivate of Egypt',
#   'Q370173': 'Sultanate of Egypt',
#   'Q124943': 'Kingdom of Egypt',
#   'Q3087763': 'Republic of Egypt (1953–1958)',
#   'Q170468': 'United Arab Republic',
#   'Q79': 'Egypt',
#   'Q902': 'Bangladesh',
#   'Q843': 'Pakistan',
#   'Q77': 'Uruguay',
#   'Q153015': 'Kingdom of Saxony',
#   'Q203493': 'Kingdom of Romania',
#   'Q842794': 'Socialist Republic of Romania',
#   'Q881': 'Vietnam',
#   'Q1045': 'Somalia',
#   'Q31747': 'Irish Free State',
#   'Q865': 'Taiwan',
#   'Q22': 'Scotland',
#   'Q784': 'Dominica',
#   'Q833': 'Malaysia',
#   'Q241': 'Cuba',
#   'Q8680': 'British Empire',
#   'Q1041': 'Senegal',
#   'Q2046345': 'Colonial Nigeria',
#   'Q1033': 'Nigeria',
#   'Q117': 'Ghana',
#   'Q215530': 'Kingdom of Ireland',
#   'Q26234937': 'First Syrian Republic',
#   'Q146885': 'Second Syrian Republic',
#   'Q858': 'Syria',
#   'Q12150341': 'Samanid Empire',
#   'Q207044': 'Ziyarid dynasty',
#   'Q273874': 'Buyid dynasty',
#   'Q189': 'Iceland',
#   'Q529605': 'Electorate of Hesse',
#   'Q27306': 'Kingdom of Prussia',
#   'Q912': 'Mali',
#   'Q71092': 'Second French Empire',
#   'Q783': 'Honduras',
#   'Q774': 'Guatemala',
#   'Q212': 'Ukraine',
#   'Q330533': 'Seventeen Provinces',
#   'Q23366230': 'Republic of Geneva',
#   'Q403': 'Serbia',
#   'Q838261': 'Federal Republic of Yugoslavia',
#   'Q37024': 'Serbia and Montenegro',
#   'Q1029': 'Mozambique',
#   'Q2444884': 'Tibet',
#   'Q3708094': 'Seljuk Empire',
#   'Q2415901': 'Allied-occupied Germany',
#   'Q884': 'South Korea',
#   'Q49683': 'Grand Duchy of Lithuania',
#   'Q172107': 'Polish–Lithuanian Commonwealth',
#   'Q763': 'Saint Kitts and Nevis',
#   'Q334': 'Singapore',
#   'Q225': 'Bosnia and Herzegovina',
#   'Q778': 'The Bahamas',
#   'Q8733': 'Qing dynasty',
#   'Q1183': 'Puerto Rico',
#   'Q131964': 'Austrian Empire',
#   'Q209857': 'Kingdom of Lombardy–Venetia',
#   'Q424': 'Cambodia',
#   'Q1027': 'Mauritius',
#   'Q33123248': 'Blackfeet Nation',
#   'Q233': 'Malta',
#   'Q114': 'Kenya',
#   'Q191': 'Estonia',
#   'Q1140152': 'Irish Republic',
#   'Q153943': 'Kingdom of Westphalia',
#   'Q2253783': 'Kingdom of Glywysing',
#   'Q954': 'Zimbabwe',
#   'Q29520': 'China',
#   'Q9903': 'Ming dynasty',
#   'Q928': 'Philippines',
#   'Q11178782': 'Czechoslovak Republic',
#   'Q853348': 'Czechoslovak Socialist Republic',
#   'Q810': 'Jordan',
#   'Q223050': 'statelessness',
#   'Q796': 'Iraq',
#   'Q1065073': 'Song',
#   'Q115': 'Ethiopia',
#   'Q3568043': 'Hawaiian Wikipedia',
#   'Q222': 'Albania',
#   'Q3995': 'Basque Autonomous Community',
#   'Q736936': 'Lu',
#   'Q142417': 'Kingdom of Valencia',
#   'Q1054923': 'British Hong Kong',
#   'Q184': 'Belarus',
#   'Q851': 'Saudi Arabia',
#   'Q262': 'Algeria',
#   'Q186096': 'Tsardom of Russia',
#   'Q140359': 'First Czechoslovak Republic',
#   'Q170072': 'Dutch Republic',
#   'Q730': 'Suriname',
#   'Q12548': 'Holy Roman Empire',
#   'Q151624': 'German Confederation',
#   'Q80702': 'Spanish Empire',
#   'Q11774': 'Gupta Empire',
#   'Q836': 'Myanmar',
#   'Q178038': 'Second Spanish Republic',
#   'Q170174': 'Papal States',
#   'Q193714': 'Mandatory Palestine',
#   'Q123559': 'al-Andalus',
#   'Q35216': 'Zhou dynasty',
#   'Q188712': 'Empire of Japan',
#   'Q55': 'Netherlands',
#   'Q28025': 'Ryukyu Kingdom',
#   'Q153529': 'Duchy of Milan',
#   'Q1037': 'Rwanda',
#   'Q686': 'Vanuatu',
#   'Q5705': 'Catalonia',
#   'Q81931': 'Confederate States of America',
#   'Q22890': 'Ireland',
#   'Q17054': 'Martinique',
#   'Q216173': 'Free City of Danzig',
#   'Q1615455': 'Duchy of Mirandola',
#   'Q244796': 'Achaean League',
#   'Q252': 'Indonesia',
#   'Q1000': 'Gabon',
#   'Q760': 'Saint Lucia',
#   'Q218023': 'Orange Free State',
#   'Q717': 'Venezuela',
#   'Q204920': 'Crown of Aragon',
#   'Q916': 'Angola',
#   'Q258532': 'British America',
#   'Q193619': 'Union of South Africa',
#   'Q945': 'Togo',
#   'Q750': 'Bolivia',
#   'Q149805': 'Kingdom of Iraq',
#   'Q800': 'Costa Rica',
#   'Q924': 'Tanzania',
#   'Q156199': 'Electorate of Saxony',
#   'Q813': 'Kyrgyzstan',
#   'Q237': 'Vatican City',
#   'Q877670': 'Muzaffarids of Iran',
#   'Q484195': 'Timurid Empire',
#   'Q23792': 'Palestine',
#   'Q8646': 'Hong Kong',
#   'Q174306': 'Republic of Genoa',
#   'Q6581823': 'Southern Netherlands',
#   'Q42406': 'English people',
#   'Q22244': 'Inglange',
#   'Q1049': 'Sudan',
#   'Q1031430': 'Habsburg Netherlands',
#   'Q683': 'Samoa',
#   'Q12544': 'Byzantine Empire',
#   'Q5843680': 'Halicarnassus',
#   'Q42585': 'Kingdom of Bohemia',
#   'Q4948': 'Republic of Venice',
#   'Q58296': 'French First Republic',
#   'Q1009': 'Cameroon',
#   'Q1014': 'Liberia',
#   'Q600093': 'Habsburg Spain',
#   'Q211': 'Latvia',
#   'Q1008': 'Ivory Coast',
#   'Q734': 'Guyana',
#   'Q929': 'Central African Republic',
#   'Q971': 'Republic of the Congo',
#   'Q699964': 'Archduchy of Austria',
#   'Q701614': 'Archbishopric of Salzburg',
#   'Q711': 'Mongolia',
#   'Q1135255': 'Chinese Soviet Republic',
#   'Q817': 'Kuwait',
#   'Q217196': 'Crown of Castile',
#   'Q14689896': 'Prairie Band of Potawatomi Nation',
#   'Q350986': 'Kuala',
#   'Q736': 'Ecuador',
#   'Q986': 'Eritrea',
#   'Q963': 'Botswana',
#   'Q9683': 'Tang dynasty',
#   'Q837': 'Nepal',
#   'Q2577303': 'Kingdom of Sardinia',
#   'Q235': 'Monaco',
#   'Q7183': 'Qin dynasty',
#   'Q34756': 'Qin',
#   'Q164079': 'Kingdom of Hanover',
#   'Q792': 'El Salvador',
#   'Q242': 'Belize',
#   'Q171150': 'Kingdom of Hungary',
#   'Q3960459': 'Kingdom of Sikkim',
#   'Q157367': 'Brandenburg-Prussia',
#   'Q583038': 'Ostrogothic Kingdom',
#   'Q712': 'Fiji',
#   'Q2017684': 'French protectorate of Tunisia',
#   'Q948': 'Tunisia',
#   'Q977': 'Djibouti',
#   'Q1011': 'Cape Verde',
#   'Q154195': 'Kingdom of Bavaria',
#   'Q556263': 'Duchy of Brunswick-Lüneburg',
#   'Q22880': 'Electoral Palatinate',
#   'Q107299': 'Kingdom of Northumbria',
#   'Q423': 'North Korea',
#   'Q278874': 'Anhalt-Dessau',
#   'Q63158027': 'Qajar Iran',
#   'Q2335224': 'Colony of Rhode Island and Plantations',
#   'Q171740': 'Caliphate of Córdoba',
#   'Q7313': 'Yuan dynasty',
#   'Q15102440': 'Kingdom of Serbs, Croats and Slovenes',
#   'Q718374': 'State of Slovenes, Croats and Serbs',
#   'Q7904317': 'Electorate of Cologne',
#   'Q622783': 'Spanish Netherlands',
#   'Q965': 'Burkina Faso',
#   'Q215': 'Slovenia',
#   'Q14708404': 'Cherokee Nation',
#   'Q836676': 'Kingdom of Majorca',
#   'Q330362': 'Commonwealth of England',
#   'Q912052': 'Wei',
#   'Q25395037': 'Kingdom of Hungary',
#   'Q2670092': 'Dominion of Ceylon',
#   'Q32': 'Luxembourg',
#   'Q2010024': 'Second Czechoslovak Republic',
#   'Q2252973': 'Duchy of Florence',
#   'Q154849': 'Grand Duchy of Tuscany',
#   'Q159856': 'Duchy of Brabant',
#   'Q159631': 'Kingdom of Württemberg',
#   'Q733': 'Paraguay',
#   'Q36704': 'Yugoslavia',
#   'Q11024667': 'Duchy of Mecklenburg-Schwerin',
#   'Q31945': 'Arabian Peninsula',
#   'Q173065': 'Kingdom of Naples',
#   'Q917': 'Bhutan',
#   'Q50001': 'Italians',
#   'Q2396442': 'Kingdom of Galicia and Lodomeria',
#   'Q696651': 'Saxe-Eisenach',
#   'Q23635': 'Bermuda',
#   'Q10957559': 'Principality of Moldavia',
#   'Q958291': 'United Principalities of Moldavia and Wallachia',
#   'Q214': 'Slovakia',
#   'Q221': 'North Macedonia',
#   'Q5103726': 'Choctaw Nation of Oklahoma',
#   'Q4398229': 'Russian state 1918-1920',
#   'Q769': 'Grenada',
#   'Q1973': 'British Columbia',
#   'Q399': 'Armenia',
#   'Q691': 'Papua New Guinea',
#   'Q244': 'Barbados',
#   'Q1044': 'Sierra Leone',
#   'Q320925': 'Shu Han',
#   'Q229': 'Cyprus',
#   'Q804': 'Panama',
#   'Q1290149': "Federal People's Republic of Yugoslavia",
#   'Q130842': 'Greater Lebanon',
#   'Q181634': 'Scottish people',
#   'Q1030': 'Namibia',
#   'Q3287203': 'Cook Islands Maori people',
#   'Q165040': 'Duchy of Parma',
#   'Q156418': 'Kingdom of Hawaiʻi',
#   'Q684030': 'Principality of Serbia',
#   'Q1020': 'Malawi',
#   'Q430309': 'Đại Việt',
#   'Q47261': 'Duchy of Bavaria',
#   'Q217169': 'Rhodesia',
#   'Q228': 'Andorra',
#   'Q71084': 'First French Empire',
#   'Q600018': 'Kingdom of Hungary'},
#  'language': {'Q1860': 'English',
#   'Q150': 'French',
#   'Q7737': 'Russian',
#   'Q652': 'Italian',
#   'Q1321': 'Spanish',
#   'Q188': 'German',
#   'Q5146': 'Portuguese',
#   'Q9056': 'Czech',
#   'Q7979': 'British English',
#   'Q9043': 'Norwegian',
#   'Q809': 'Polish',
#   'Q7976': 'American English',
#   'Q5287': 'Japanese',
#   'Q8641': 'Yiddish',
#   'Q35497': 'Ancient Greek',
#   'Q13955': 'Arabic',
#   'Q9067': 'Hungarian',
#   'Q8097': 'Telugu',
#   'Q9027': 'Swedish',
#   'Q1412': 'Finnish',
#   'Q397': 'Latin',
#   'Q9129': 'Greek',
#   'Q5137': 'Gujarati',
#   'Q750553': 'Brazilian Portuguese',
#   'Q9035': 'Danish',
#   'Q7026': 'Catalan',
#   'Q256': 'Turkish',
#   'Q36395': 'Middle English',
#   'Q25164': 'Nynorsk',
#   'Q1473289': 'Middle French',
#   'Q9192': 'Mandarin Chinese',
#   'Q12107': 'Breton',
#   'Q7913': 'Romanian',
#   'Q14196': 'Afrikaans',
#   'Q8752': 'Basque',
#   'Q8748': 'Albanian',
#   'Q11059': 'Sanskrit',
#   'Q9186': 'Cantonese',
#   'Q1568': 'Hindi',
#   'Q14549': 'Scots',
#   'Q1553250': 'Scottish English',
#   'Q44676': 'Canadian English',
#   'Q9142': 'Irish',
#   'Q9083': 'Lithuanian',
#   'Q1571': 'Marathi',
#   'Q7411': 'Dutch',
#   'Q36510': 'Modern Greek',
#   'Q9288': 'Hebrew',
#   'Q143': 'Esperanto',
#   'Q294': 'Icelandic',
#   'Q9168': 'Persian',
#   'Q10134': 'Klingon',
#   'Q7850': 'Chinese',
#   'Q18130932': 'Traditional Chinese',
#   'Q1472196': 'Early Modern English',
#   'Q9610': 'Bengali',
#   'Q9176': 'Korean',
#   'Q36236': 'Malayalam',
#   'Q32724': 'Venetian',
#   'Q37041': 'Classical Chinese',
#   'Q5364419': 'Early Modern Spanish',
#   'Q34057': 'Tagalog',
#   'Q2631909': 'Castilian Spanish',
#   'Q13300': 'Nahuatl',
#   'Q35222': 'Old French',
#   'Q33673': 'Kannada',
#   'Q9199': 'Vietnamese',
#   'Q9309': 'Welsh',
#   'Q33856': 'Papiamento',
#   'Q1617': 'Urdu',
#   'Q9301': 'Serbo-Croatian',
#   'Q9299': 'Serbian',
#   'Q34311': 'Yoruba',
#   'Q37015': 'Riksmål',
#   'Q9063': 'Slovene',
#   'Q15478520': 'Old Catalan',
#   'Q14185': 'Occitan',
#   'Q9314': 'Scottish Gaelic',
#   'Q33441': 'Friulian',
#   'Q36387': 'Medieval Greek',
#   'Q7918': 'Bulgarian',
#   'Q9307': 'Galician',
#   'Q13199': 'Romansh',
#   'Q35961': 'Katharevousa',
#   'Q33273': 'Chewa'},
#  'religion': {'Q93191': 'Baptists',
#   'Q1351880': 'Southern Baptist Convention',
#   'Q620629': 'deism',
#   'Q13211738': 'atheist',
#   'Q6423963': 'Anglicanism',
#   'Q9268': 'Judaism',
#   'Q9592': 'Catholic Church',
#   'Q288928': 'agnosticism',
#   'Q7066': 'atheism',
#   'Q1841': 'Catholicism',
#   'Q178169': 'Presbyterianism',
#   'Q7953': 'Zen',
#   'Q9089': 'Hinduism',
#   'Q75809': 'Lutheranism',
#   'Q1622507': 'Unitarian Universalism',
#   'Q7361618': 'Roman Catholic',
#   'Q5043': 'Christianity',
#   'Q3333484': 'Eastern Orthodoxy',
#   'Q657907': 'Tolstoyan movement',
#   'Q682443': 'Episcopal Church',
#   'Q312226': 'secular humanism',
#   'Q1062789': 'congregational church',
#   'Q106687': 'Unitarianism',
#   'Q748': 'Buddhism',
#   'Q329646': 'United Methodist Church',
#   'Q33203': 'Methodism',
#   'Q1069127': 'Lapsed Catholic',
#   'Q42504': 'The Church of Jesus Christ of Latter-day Saints',
#   'Q214255': 'spiritism',
#   'Q107475247': 'Pajero',
#   'Q624477': 'Christian Science',
#   'Q2869299': 'Jewish atheism',
#   'Q7970362': 'Greek Orthodox Church',
#   'Q101849': 'Calvinism',
#   'Q131036': 'Scientology',
#   'Q58721': 'irreligion',
#   'Q23540': 'Protestantism',
#   'Q45996': 'mysticism',
#   'Q10312696': 'secular Judaism',
#   'Q131165': 'Manichaeism',
#   'Q60995': 'Russian Orthodox Church',
#   'Q494890': 'Assemblies of God',
#   'Q205644': 'Conservative Judaism',
#   'Q194253': 'Evangelicalism',
#   'Q541235': 'Anglo-Catholicism',
#   'Q483889': 'Tibetan Buddhism',
#   'Q1571776': 'Rimé movement',
#   'Q432': 'Islam',
#   'Q59774': 'Wicca',
#   'Q189753': 'modern Paganism',
#   'Q111077083': 'Franciscan spirituality',
#   'Q657488': 'perennial philosophy',
#   'Q1771622': 'Modern Orthodox Judaism',
#   'Q181901': 'Romanian Orthodox Church',
#   'Q346575': 'evangelical church',
#   'Q42042': 'shamanism',
#   'Q82708': 'Church of England',
#   'Q1755789': 'The New Church',
#   'Q745955': 'Thelema',
#   'Q3866624': 'Goddess movement',
#   'Q35032': 'Eastern Orthodox Church',
#   'Q42388': 'Zionism',
#   'Q728455': 'pantheism',
#   'Q337547': 'ancient Roman religion',
#   'Q46158': 'humanism',
#   'Q2062042': 'Unity Church',
#   'Q483978': 'Pentecostalism',
#   'Q7049261': 'Nondenominational Christianity',
#   'Q426316': 'United Church of Christ',
#   'Q101462': 'Rastafari movement',
#   'Q1541206': 'Christian Church (Disciples of Christ)',
#   'Q855941': 'Restorationism',
#   'Q1287654': 'Surmang-Kagyü',
#   'Q184719': 'anthroposophy',
#   'Q132265': 'Theravāda',
#   'Q483654': 'Sunni Islam',
#   'Q7233501': 'Elder',
#   'Q1133485': 'reform Judaism',
#   'Q6926246': 'Buddhist',
#   'Q97378570': 'Orthodox Christian',
#   'Q172904': 'syncretism',
#   'Q8068963': 'Zen Peacemakers',
#   'Q2272897': 'Alliance World Fellowship',
#   'Q16547842': 'unbelief',
#   'Q106039': 'Christian',
#   'Q220222': 'Nation of Islam',
#   'Q170208': 'Quakers',
#   'Q855270': 'religion in ancient Greece',
#   'Q22679': 'Baháʼí Faith',
#   'Q104319': 'Seventh-day Adventist Church',
#   'Q9581': 'Confucianism',
#   'Q2136834': 'Reformed Church in America',
#   'Q216952': 'Messianic Judaism',
#   'Q3091361': 'evangelism',
#   'Q13631353': 'Evangelical',
#   'Q170111': 'Evangelical Church in Germany',
#   'Q1149100': 'Presbyterian Church (U.S.A.)',
#   'Q323301': 'Greek Orthodox Church of Antioch',
#   'Q1523459': 'Stregheria',
#   'Q328945': 'Thomism',
#   'Q9598': 'Taoism',
#   'Q7248639': 'Progressive Christianity',
#   'Q927277': 'Santería',
#   'Q1454631': 'religious humanism',
#   'Q101000920': 'Tantric Buddhism',
#   'Q620016': 'Christian atheism',
#   'Q18245005': 'Congregationalism in the United States',
#   'Q29536': 'paganism',
#   'Q49830': 'Continental Reformed Protestantism',
#   'Q471244': 'Evangelical Association',
#   'Q9603': 'Sufism',
#   'Q875668': 'Church of Ireland',
#   'Q2122370': 'Reformed Baptists',
#   'Q1287': 'jansenism',
#   'Q256223': 'LaVeyan Satanism',
#   'Q182320': 'Mennonite Church in the Netherlands',
#   'Q35269': "Jehovah's Witnesses",
#   'Q161362': 'Confessing Church',
#   'Q922480': 'Church of Scotland',
#   'Q7487456': 'Shambhala Buddhism',
#   'Q110223': 'Mennonites',
#   'Q856349': 'Romanian Greek Catholic Church',
#   'Q34651': 'Christian Church',
#   'Q782911': 'Evangelical Church of Czech Brethren',
#   'Q960252': 'Congregationalist polity',
#   'Q3586152': 'Episcopal Church',
#   'Q597526': 'Latin Church',
#   'Q2671570': 'Dudeism',
#   'Q2479801': 'Ietsism',
#   'Q1189165': 'Church of the Nazarene',
#   'Q639625': 'Rinzai school',
#   'Q694002': 'Orthodox Church in America',
#   'Q6908412': 'Moorish Orthodox Church of America',
#   'Q9585': 'Shia Islam',
#   'Q53997857': 'indefinite',
#   'Q123006': 'Kabbalah',
#   'Q137073': 'Puritanism',
#   'Q1088552': 'Catholic church building',
#   'Q584205': 'Nontrinitarianism',
#   'Q848771': 'Nyingma',
#   'Q217059': 'Unification Church',
#   'Q11085': "Parkinson's disease",
#   'Q384121': 'African Methodist Episcopal Church',
#   'Q36886569': 'Catholic',
#   'Q9316': 'Sikhism',
#   'Q188814': 'Serbian Orthodox Church',
#   'Q9163': 'polytheism',
#   'Q12899500': 'Cristiano',
#   'Q517609': 'agnostic atheism',
#   'Q171764': 'Ahmadiyya',
#   'Q9232': 'Jainism',
#   'Q178671': 'theosophy',
#   'Q3493578': 'Spiritual but not religious',
#   'Q7425926': 'Satanis',
#   'Q617717': 'Soka Gakkai',
#   'Q18614578': 'Atheists',
#   'Q683724': 'Armenian Apostolic Church',
#   'Q385517': 'Oomoto',
#   'Q631897': 'Raelism',
#   'Q540782': 'Anglican Church of Canada',
#   'Q3559237': 'Evangelical Presbyterian Church',
#   'Q6016400': 'Independent Baptist',
#   'Q749085': 'Sōtō',
#   'Q17549077': 'Catholic',
#   'Q10090': 'Hindu',
#   'Q3269815': 'Anglican Church in North America',
#   'Q32078': 'Naqshbandi',
#   'Q471187': 'Kagyu',
#   'Q871396': 'nontheism',
#   'Q1933925': 'Association of Vineyard Churches',
#   'Q80970': 'Orthodox Judaism',
#   'Q29568419': 'catholic',
#   'Q2892720': 'Sufi',
#   'Q262244': 'Pure Land Buddhism',
#   'Q64900': 'Maronite Church',
#   'Q2638583': 'Western Rite Orthodoxy',
#   'Q829348': 'spiritualism',
#   'Q1426400': 'Homaranismo',
#   'Q171201': 'Hasidism',
#   'Q206611': 'Nichiren Shū',
#   'Q5116896': 'Church of Hawaii',
#   'Q324640': 'Charismatic Movement',
#   'Q539918': "Ash'ari",
#   'Q515880': 'Dutch Reformed Church',
#   'Q871371': 'Nichiren Buddhism'},
#  'gender': {'Q6581097': 'male',
#   'Q6581072': 'female',
#   'Q1052281': 'transgender female',
#   'Q48270': 'non-binary',
#   'Q2449503': 'transgender male',
#   'Q18116794': 'genderfluid',
#   'Q1097630': 'intersex',
#   'Q27679684': 'transfeminine'},
#  'ethnicity': {'Q49085': 'African Americans',
#   'Q842438': 'Britons',
#   'Q170826': 'Irish people',
#   'Q42406': 'English people',
#   'Q49078': 'white Americans',
#   'Q7325': 'Jewish people',
#   'Q1026': 'Poles',
#   'Q164714': 'Danes',
#   'Q7994501': 'White British',
#   'Q1344183': 'English American',
#   'Q42884': 'Germans',
#   'Q704608': 'Turks in Germany',
#   'Q115026': 'Swedish American',
#   'Q181634': 'Scottish people',
#   'Q1196645': 'Canadians',
#   'Q678551': 'American Jews',
#   'Q846570': 'Americans',
#   'Q1276073': 'Chileans',
#   'Q34069': 'Ashkenazi Jews',
#   'Q992401': 'Brulé',
#   'Q107434': 'Sioux',
#   'Q49542': 'Russians',
#   'Q50001': 'Italians',
#   'Q324216': 'Austrian Americans',
#   'Q121842': 'French',
#   'Q1075293': 'Irish Americans',
#   'Q255872': 'Ojibwe',
#   'Q974693': 'Italian Americans',
#   'Q2606511': 'Lebanese',
#   'Q200569': 'Dutch',
#   'Q1369944': 'French American',
#   'Q141817': 'German Americans',
#   'Q3476361': 'Scottish American',
#   'Q1140588': 'Russian Americans',
#   'Q160894': 'Spaniards',
#   'Q5029681': 'Canadian American',
#   'Q79797': 'Armenians',
#   'Q165192': 'Swedes',
#   'Q1800513': 'Laguna people',
#   'Q2704511': 'White Africans of European ancestry',
#   'Q45315': 'Berbers',
#   'Q161652': 'Japanese people',
#   'Q3015339': 'Danish Americans',
#   'Q539051': 'Greeks',
#   'Q902325': 'Tsonga people',
#   'Q1189552': 'Polish Americans',
#   'Q133032': 'Hungarians',
#   'Q852205': 'Monguor people',
#   'Q187985': 'Tibetan people',
#   'Q6158431': 'Japanese community in the United Kingdom',
#   'Q483505': 'Tajiks',
#   'Q44806': 'Ukrainians',
#   'Q188353': 'Welsh people',
#   'Q235155': 'white people',
#   'Q2325516': 'Armenian American',
#   'Q188779': 'Norwegians',
#   'Q173491': 'Tamil',
#   'Q105405': 'Cherokee',
#   'Q1318423': 'Australians',
#   'Q472834': 'Thai people',
#   'Q1061510': 'Egyptians',
#   'Q178630': 'Portuguese',
#   'Q570868': 'Evrei',
#   'Q216151': 'Vietnamese people',
#   'Q241696': 'Somalis',
#   'Q4172847': 'Filipino people',
#   'Q1651392': 'Roman people',
#   'Q84072': 'Turks',
#   'Q4823807': 'Australian American',
#   'Q1156766': 'Japanese American',
#   'Q2031644': 'history of the Jews in Russia',
#   'Q581921': 'Mexican American',
#   'Q237534': 'Austrians',
#   'Q7435494': 'Scotch-Irish Americans',
#   'Q244157': 'Igbo people',
#   'Q6071674': 'Irish migration to Great Britain',
#   'Q726673': 'Swedish-speaking population of Finland',
#   'Q63075063': 'Jewish people of Ukraine',
#   'Q2849692': 'Anglo-Irish people',
#   'Q484206': 'Persians',
#   'Q167420': 'Croats',
#   'Q1144501': "Gwich'in people",
#   'Q6105755': 'Alaskan Athabaskans',
#   'Q7129609': 'Caucasian',
#   'Q2643509': 'Indian Americans',
#   'Q518188': 'Czech Americans',
#   'Q127885': 'Serbs',
#   'Q8060': 'Romani',
#   'Q368125': 'Anglo Indian people',
#   'Q1150312': 'Greek American',
#   'Q17511776': 'Americans in Germany',
#   'Q124216': 'Swiss',
#   'Q837881': 'Lemkos',
#   'Q170217': 'Czechs',
#   'Q157139': 'Baltic Germans',
#   'Q388315': 'African Brazilian',
#   'Q7507476': 'Sicilian Americans',
#   'Q6127476': 'African Jamaican',
#   'Q2598589': 'Armenians in Russia',
#   'Q686949': 'Cajun',
#   'Q485150': 'Romanians',
#   'Q190168': 'Yoruba people',
#   'Q262457': 'Métis',
#   'Q1146100': 'Chinese Americans',
#   'Q1779499': 'Thembu tribe',
#   'Q318806': 'Abenaki people',
#   'Q179248': 'Albanians',
#   'Q7541523': 'Slovak Americans',
#   'Q1137419': 'Quiché',
#   'Q131242': 'Eskimo',
#   'Q145665': 'Manchu',
#   'Q42740': 'Han Chinese people',
#   'Q126756': 'Basque people',
#   'Q2657969': 'Vietnamese Americans',
#   'Q1289780': 'Jew',
#   'Q49209': 'Javanese people',
#   'Q943349': 'Padaung people',
#   'Q5894222': 'Hong Kong American',
#   'Q622728': 'Chickasaw',
#   'Q191356': 'Icelanders',
#   'Q102251': 'Sephardi Jews',
#   'Q1282294': 'Gujarati people',
#   'Q6501380': 'Chinese people',
#   'Q333049': 'Lakota people',
#   'Q110884043': 'Italian English',
#   'Q640605': 'Yamato people',
#   'Q5094611': 'Cheyenne and Arapaho Tribes',
#   'Q2527423': 'Ilocano people',
#   'Q392316': 'First Nations',
#   'Q1378555': 'mixed race people',
#   'Q147239': 'Kashubians',
#   'Q106991': 'Chukchi people',
#   'Q1267849': 'Indo-Aryan peoples',
#   'Q1956640': 'Anishinaabe',
#   'Q5555460': 'Ghanaian American',
#   'Q116971': 'Mohawk people',
#   'Q388264': 'Blackfoot Confederacy',
#   'Q369497': 'Armenians in Istanbul',
#   'Q5602105': 'Greeks in Turkey',
#   'Q49297': 'Native Americans in the United States',
#   'Q491755': "Coeur d'Alene people",
#   'Q6935055': 'Multiracial American',
#   'Q117191': 'Cree',
#   'Q16129257': 'Jewish people in Eastern Europe',
#   'Q805': 'Yemen',
#   'Q36747': 'indigenous peoples of the Americas',
#   'Q520663': 'Germans of Hungary',
#   'Q18973': 'Georgians',
#   'Q133255': 'Bulgarians',
#   'Q1058496': 'Dutch American',
#   'Q3094841': 'Welsh American',
#   'Q1421205': 'Lithuanian Jews',
#   'Q12223': 'Kurds',
#   'Q1509140': 'Okanagan people',
#   'Q695067': 'Colville tribe',
#   'Q857880': 'French Canadians',
#   'Q702718': 'British Jews',
#   'Q15916203': 'Чэхі, племя',
#   'Q1123411': 'Carians',
#   'Q4269361': 'Greek Australian',
#   'Q402913': 'Bengali people',
#   'Q47140': 'Brahmin',
#   'Q106713': 'mestizo',
#   'Q2338367': 'Greeks in Egypt',
#   'Q34344': 'Yurok people',
#   'Q381151': 'Walloons',
#   'Q3513756': 'Haisla people',
#   'Q815763': 'Heiltsuk people',
#   'Q1898438': 'Masurians',
#   'Q1065583': 'Potawatomi',
#   'Q110886759': 'Lebanese French',
#   'Q171336': 'Slovaks',
#   'Q28': 'Hungary',
#   'Q1749358': 'Lithuanian American',
#   'Q893594': 'Puerto Ricans',
#   'Q5639720': 'Haitian American',
#   'Q727928': 'Asian Americans',
#   'Q6432084': 'Koreans in the United Kingdom',
#   'Q32360797': 'Russian Jews',
#   'Q483569': 'Belarusians',
#   'Q10312754': 'Japanese Canadians',
#   'Q1478209': 'Ogoni people',
#   'Q1737293': 'Miniconjou',
#   'Q1377716': 'Belgians',
#   'Q3916714': 'Romanian Americans',
#   'Q210332': 'Haida people',
#   'Q2505231': 'Ukrainian American',
#   'Q3573855': 'Castilians',
#   'Q2408653': 'Thai Chinese people',
#   'Q51705': 'Muscogee',
#   'Q3566326': 'Tenino people',
#   'Q5948733': 'Wasco',
#   'Q108266': 'Navajo',
#   'Q445618': 'Banat Swabians',
#   'Q700469': 'Germans of Romania',
#   'Q3026382': 'Italian French',
#   'Q35323': 'Arabs',
#   'Q242485': 'Flemings',
#   'Q4386404': 'Louisiana Creole people',
#   'Q207996': 'Xhosa people',
#   'Q1157179': 'Dagaaba people',
#   'Q129962': 'Zulu people',
#   'Q245507': 'Quebeckers',
#   'Q170284': 'Finns',
#   'Q2599466': 'Yankton',
#   'Q463180': 'American',
#   'Q1790886': 'Cuban American',
#   'Q28224441': 'Waanyi',
#   'Q1943269': 'Mokshas',
#   'Q18420435': 'Syriac people',
#   'Q3003133': 'brazilen',
#   'Q1436196': 'Afshar tribe',
#   'Q752526': 'Galicians',
#   'Q2587830': 'Pardo Brazilians',
#   'Q817393': 'black people',
#   'Q30': 'United States of America',
#   'Q7409937': 'Samoan American',
#   'Q117255': 'Hopi people',
#   'Q8055853': 'Yorta Yorta people',
#   'Q1193808': 'Norwegian Americans',
#   'Q12826303': 'Luo people of Kenya and Tanzania',
#   'Q6392846': 'Kenyan Americans',
#   'Q6025584': 'Indo-Trinidadians and Tobagonians',
#   'Q1429504': 'Kickapoo people',
#   'Q43103': 'European Americans',
#   'Q637979': 'Swiss Americans',
#   'Q2886395': 'Basque American',
#   'Q4969868': 'British Cypriots',
#   'Q1065371': 'Italian Brazilians',
#   'Q28195536': 'Romanian Jews',
#   'Q16242047': 'Criollo people',
#   'Q577576': 'Sotho people',
#   'Q7258666': 'Stateside Puerto Ricans',
#   'Q101828': 'Ainu people',
#   'Q4858560': 'Barbadian American',
#   'Q858': 'Syria',
#   'Q1307911': 'chicano',
#   'Q875556': 'Israelis',
#   'Q25688688': 'ancient Greeks',
#   'Q324516': 'Choctaw',
#   'Q2426677': 'Iranian Azerbaijanis',
#   'Q2006701': 'Northern Cheyenne Tribe',
#   'Q2012419': 'Russians in Latvia',
#   'Q1261777': 'Serbian Americans',
#   'Q4272184': 'Luxembourgish Americans',
#   'Q932244': 'Sinhalese',
#   'Q750947': 'Pawnee people',
#   'Q7108926': 'Otoe-Missouria Tribe of Indians',
#   'Q2140968': 'Sardinians',
#   'Q331789': 'Crow Nation',
#   'Q6510842': 'Lebanese American',
#   'Q68518': 'Haudenosaunee Confederacy',
#   'Q4969461': 'British Arabs',
#   'Q2464565': 'Turkish Americans',
#   'Q186192': 'Lithuanians',
#   'Q101935': 'Huguenot',
#   'Q6127409': 'Jamaican American',
#   'Q16242628': 'African diaspora in the Americas'}}

# %%
for col in authors.columns[9:-2]:
    lista = authors[col]
    new_lista = []
    for item in lista:
        if item!="":
            items = item.split(", ")
            new_items = []
            for it in items:
                new_it = property_labels[col][it]
                new_items.append(new_it)
            new_items = ", ".join(new_items)
        else: 
            new_items = ""
        new_lista.append(new_items)
    authors[col] = new_lista
    print(col)
# Out:
# sexuality
# country
# language
# religion
# gender
# ethnicity

# %%
authors["gender"].unique()
# Out:
# array(['male', 'female', '', 'transgender female', 'non-binary, female',
#        'transgender male', 'transgender female, female', 'non-binary',
#        'male, female', 'genderfluid, male', 'female, male', 'intersex',
#        'intersex, non-binary', 'female, intersex', 'transfeminine, male'],
#       dtype=object)

# %%
len(authors)
# Out:
# 39642

# %% [markdown]
# # DONE!

# %%
authors.to_csv("data/final_authors_after_properties_and_decoding.csv")
