# %%
import time
import pandas as pd
import numpy as np
import pickle as pkl
from collections import Counter
import re
import math
import matplotlib.pyplot as plt
from mycolorpy import colorlist as mcp
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from pywaffle import Waffle
from scipy.signal import find_peaks
from itertools import chain

# %%
location_to_save = "data/final_files/"
large_location_to_save = "data/final_files/large_files/"

# %%
b = pd.read_csv(location_to_save + "items_books_some_isbn.csv", low_memory = False, index_col=0).fillna("").iloc[:106000]

# %%
b[b.alt_title=='']
# Out:
#               ISBN                                              title  \
# 7       0671870432                                    PLEADING GUILTY
# 13      1552041778                                           Jane Doe
# 15      1567407781       The Witchfinder (Amos Walker Mystery Series)
# 66      042511774X                                  Breathing Lessons
# 71      1414035004  The Adventures of Drew and Ellie: The Magical ...
# ...            ...                                                ...
# 106995  0094688400  Good King Richard?: An Account of Richard III ...
# 106996  0192815687                Four Major Plays (World's Classics)
# 106997  0333361458       The Jungle Bk Pr Refer To Pan Book Kipling R
# 106998  0140440445  The Bacchae and Other Plays (The Penguin Class...
# 106999  0192810545                   Plays; (Oxford paperbacks, 216-)
#
#                    author  year                 publisher alt_title alt_author
# 7             Scott Turow  1993                Audioworks
# 13           R. J. Kaiser  1999                Mira Books
# 15      Loren D. Estleman  1998  Brilliance Audio - Trade
# 66             Anne Tyler  1994  Berkley Publishing Group
# 71         Charles Noland  2003          1stBooks Library
# ...                   ...   ...                       ...       ...        ...
# 106995      Jeremy Potter  1994          Trafalgar Square
# 106996       Henrik Ibsen  1982   Oxford University Press
# 106997    Rudyard Kipling  1996             Pan Macmillan
# 106998          Euripides  1954             Penguin Books
# 106999       Aristophanes  1970   Oxford University Press
#
# [4774 rows x 7 columns]

# %%
len(b[b.alt_title==''])
# Out:
# 3775

# %%
b
# Out:
#               ISBN                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 105995  0373286414      Highland Barbarian (Harlequin Historical, 41)
# 105996  037305310X          Love Medicine (Silhouette Desire, No 310)
# 105997  0373074042  Sir Flynn And Lady Constance (Silhouette Intim...
# 105998  037328845X               Angel (Harlequin Historical, No 245)
# 105999  031046482X                               Anna's Rocking Chair
#
#                       author  year                publisher  \
# 0         Mark P. O. Morford  2002  Oxford University Press
# 1       Richard Bruce Wright  2001    HarperFlamingo Canada
# 2               Carlo D'Este  1991          HarperPerennial
# 3           Gina Bari Kolata  1999     Farrar Straus Giroux
# 4            E. J. W. Barber  1999   W. W. Norton & Company
# ...                      ...   ...                      ...
# 105995           Ruth Langan  1990                Harlequin
# 105996         Suzanne Carey  1986               Silhouette
# 105997           Maura Seger  1991               Silhouette
# 105998           Ruth Langan  1994                Harlequin
# 105999         Elaine Watson  1984                Zondervan
#
#                            alt_title                             alt_author
# 0                Classical Mythology  Mark P. O. Morford|Robert J. Lenardon
# 1                       Clara Callan                   Richard Bruce Wright
# 2               Decision in Normandy                           Carlo D'Este
# 3                                Flu                       Gina Bari Kolata
# 4             The Mummies of Ürümchi                        E. J. W. Barber
# ...                              ...                                    ...
# 105995            Highland Barbarian                       Ruth Ryan Langan
# 105996                 Love Medicine                          Suzanne Carey
# 105997  Sir Flynn and Lady Constance                            Maura Seger
# 105998                         Angel                            Ruth Langan
# 105999          Anna's Rocking Chair                          Elaine Watson
#
# [106000 rows x 7 columns]
